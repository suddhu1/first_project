# %%
import pandas as pd

# %%
import pandas as pd 
df = pd.read_csv(r'C:\Users\santo\OneDrive\Desktop\ml_project\gemstone.csv')

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df = df.drop(labels =['id'],axis=1)

# %%
x = df.drop(labels=['price'],axis=1)

# %%
x
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
y= df[["price"]]

# %%
y
# Out:
#         price
# 0       13619
# 1       13387
# 2        2772
# 3         666
# 4       14453
# ...       ...
# 193568   1130
# 193569   2874
# 193570   3036
# 193571    681
# 193572   2258
#
# [193573 rows x 1 columns]

# %%
import numpy as np 
y = df['price'].to_numpy().ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 10 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    193573 non-null  float64
#  1   cut      193573 non-null  object
#  2   color    193573 non-null  object
#  3   clarity  193573 non-null  object
#  4   depth    193573 non-null  float64
#  5   table    193573 non-null  float64
#  6   x        193573 non-null  float64
#  7   y        193573 non-null  float64
#  8   z        193573 non-null  float64
#  9   price    193573 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 14.8+ MB

# %%
y
# Out:
# array([13619, 13387,  2772, ...,  3036,   681,  2258])

# %%
categorical_column =x.select_dtypes(include="object").columns
numerical_column = x.select_dtypes(exclude="object").columns

# %%
numerical_column
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %% [markdown]
# # pipeline
#
# imputer
#
# encoding
#
# scaling

# %%
cut_categories=['Premium', 'Very Good', 'Ideal', 'Good', 'Fair']
color_categories=['F', 'J', 'G', 'E', 'D', 'H', 'I']
clarity_categories=['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1']

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
num_pipeline =Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')),
        ('scaler',StandardScaler()),

        

    ]
)
cat_pipeline=Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy="most_frequent")),
        ('encoding',OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories])),
    ]
)

preprocessor =ColumnTransformer(
    [
        ('num_pipeline',num_pipeline,numerical_column),
        ('categorical_pipeline',cat_pipeline,categorical_column)
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                 ('categorical_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoding',
#                                                   OrdinalEncoder(categories=[['Premium',
#                                                                               'Very '
#                                                                               'Good',
#                                                                               'Ideal',
#                                                                               'Good',
#                                                                               'Fair'],
#                                                                              ['F',
#                                                                               'J',
#                                                                               'G',
#                                                                               'E',
#                                                                               'D',
#                                                                               'H',
#                                                                               'I'],
#                                                                              ['VS2',
#                                                                               'SI2',
#                                                                               'VS1',
#                                                                               'SI1',
#                                                                               'IF',
#                                                                               'VVS2',
#                                                                               'VVS1',
#                                                                               'I1']]))]),
#                                  Index(['cut', 'color', 'clarity'], dtype='object'))])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=30)

# %%
x_train
# Out:
#         carat      cut color clarity  depth  table     x     y     z
# 168192   0.34    Ideal     I    VVS2   60.9   57.0  4.56  4.53  2.76
# 35202    0.90     Good     E     SI1   63.8   57.0  6.07  6.03  3.87
# 41091    1.02  Premium     G     VS1   62.7   58.0  6.35  6.39  4.00
# 31239    0.32  Premium     G     VS2   62.1   59.0  4.37  4.35  2.71
# 45722    0.35    Ideal     J    VVS2   61.1   56.0  4.53  4.57  2.78
# ...       ...      ...   ...     ...    ...    ...   ...   ...   ...
# 66455    0.31    Ideal     E     SI1   61.8   56.0  4.31  4.35  2.68
# 46220    1.25    Ideal     G     SI2   62.0   56.0  6.88  6.95  4.28
# 98804    1.00     Good     G     SI1   63.5   56.0  6.29  6.37  4.02
# 48045    1.10    Ideal     G     VS1   59.9   60.0  6.68  6.77  4.01
# 169765   0.91    Ideal     G     SI1   62.7   57.0  6.14  6.18  3.86
#
# [135501 rows x 9 columns]

# %%
preprocessor.fit_transform(x_train)
# Out:
# array([[-0.97543926, -0.84960654, -0.12153081, ...,  2.        ,
#          6.        ,  5.        ],
#        [ 0.2351953 ,  1.83363716, -0.12153081, ...,  3.        ,
#          3.        ,  3.        ],
#        [ 0.49461699,  0.81585507,  0.39980029, ...,  0.        ,
#          2.        ,  2.        ],
#        ...,
#        [ 0.45138004,  1.55606023, -0.6428619 , ...,  3.        ,
#          2.        ,  3.        ],
#        [ 0.66756478, -1.77486298,  1.44246248, ...,  2.        ,
#          2.        ,  2.        ],
#        [ 0.25681377,  0.81585507, -0.12153081, ...,  2.        ,
#          2.        ,  3.        ]])

# %%
x_train = pd.DataFrame(preprocessor.fit_transform(x_train),columns=preprocessor.get_feature_names_out())

# %%
x_train
# Out:
#         num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 -0.975439            -0.849607            -0.121531
# 1                  0.235195             1.833637            -0.121531
# 2                  0.494617             0.815855             0.399800
# 3                 -1.018676             0.260701             0.921131
# 4                 -0.953821            -0.664555            -0.642862
# ...                     ...                  ...                  ...
# 135496            -1.040295            -0.016876            -0.642862
# 135497             0.991842             0.168176            -0.642862
# 135498             0.451380             1.556060            -0.642862
# 135499             0.667565            -1.774863             1.442462
# 135500             0.256814             0.815855            -0.121531
#
#         num_pipeline__x  num_pipeline__y  num_pipeline__z  \
# 0             -1.042757        -1.080970        -1.123150
# 1              0.318447         0.279859         0.485354
# 2              0.570855         0.606458         0.673737
# 3             -1.214034        -1.244270        -1.195605
# 4             -1.069801        -1.044681        -1.094168
# ...                 ...              ...              ...
# 135496        -1.268122        -1.244270        -1.239078
# 135497         1.048629         1.114501         1.079486
# 135498         0.516768         0.588314         0.702719
# 135499         0.868337         0.951202         0.688228
# 135500         0.381549         0.415942         0.470863
#
#         categorical_pipeline__cut  categorical_pipeline__color  \
# 0                             2.0                          6.0
# 1                             3.0                          3.0
# 2                             0.0                          2.0
# 3                             0.0                          2.0
# 4                             2.0                          1.0
# ...                           ...                          ...
# 135496                        2.0                          3.0
# 135497                        2.0                          2.0
# 135498                        3.0                          2.0
# 135499                        2.0                          2.0
# 135500                        2.0                          2.0
#
#         categorical_pipeline__clarity
# 0                                 5.0
# 1                                 3.0
# 2                                 2.0
# 3                                 0.0
# 4                                 5.0
# ...                               ...
# 135496                            3.0
# 135497                            1.0
# 135498                            3.0
# 135499                            2.0
# 135500                            3.0
#
# [135501 rows x 9 columns]

# %%
x_test = pd.DataFrame(preprocessor.transform(x_test),columns=preprocessor.get_feature_names_out())

# %%
x_test
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                -0.564688            -0.942132            -0.642862
# 1                -0.175556             1.000906            -0.121531
# 2                -1.061913             0.260701            -0.121531
# 3                 0.970223            -0.201927             1.963794
# 4                -0.932202            -1.312235             0.399800
# ...                    ...                  ...                  ...
# 58067             1.013460             1.185958            -0.642862
# 58068            -0.997058             0.260701            -1.164193
# 58069            -0.197174            -3.347799             1.442462
# 58070            -0.824110            -0.201927            -0.121531
# 58071             2.613227            -0.757081             1.442462
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  \
# 0            -0.429765        -0.464061        -0.500036
# 1            -0.042137        -0.028595         0.036132
# 2            -1.304180        -1.298703        -1.268060
# 3             1.048629         0.996563         0.978049
# 4            -1.006699        -0.990248        -1.065186
# ...                ...              ...              ...
# 58067         1.003556         1.041924         1.151941
# 58068        -1.141917        -1.126331        -1.108659
# 58069         0.102096         0.071199        -0.224706
# 58070        -0.853450        -0.881382        -0.876803
# 58071         2.139394         2.039865         2.006912
#
#        categorical_pipeline__cut  categorical_pipeline__color  \
# 0                            0.0                          3.0
# 1                            1.0                          5.0
# 2                            2.0                          5.0
# 3                            0.0                          2.0
# 4                            0.0                          3.0
# ...                          ...                          ...
# 58067                        1.0                          5.0
# 58068                        2.0                          0.0
# 58069                        0.0                          1.0
# 58070                        2.0                          2.0
# 58071                        0.0                          1.0
#
#        categorical_pipeline__clarity
# 0                                0.0
# 1                                3.0
# 2                                4.0
# 3                                0.0
# 4                                2.0
# ...                              ...
# 58067                            0.0
# 58068                            6.0
# 58069                            0.0
# 58070                            3.0
# 58071                            0.0
#
# [58072 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
    'SVR':SVR(),
   'DTR': DecisionTreeClassifier()
}

# %%
list(models)
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet', 'SVR', 'DTR']

# %%
len(list(models))
# Out:
# 6

# %%
for i in range(len(list(models))):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
models.values()
# Out:
# dict_values([LinearRegression(), Lasso(), Ridge(), ElasticNet(), SVR(), DecisionTreeClassifier()])

# %%
list(models.values())
# Out:
# [LinearRegression(),
#  Lasso(),
#  Ridge(),
#  ElasticNet(),
#  SVR(),
#  DecisionTreeClassifier()]

# %%
list(models.values())[1]
# Out:
# Lasso()

# %%
import numpy as np 
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2_square = r2_score(y_true, y_pred)
    return mae, rmse, r2_square

# %%
## Train multiple models 

models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
    'SVR':SVR(),
   'DTR': DecisionTreeClassifier()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train,y_train)

    # make predictions 
    y_pred=model.predict(x_test)

    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance ')
    print('RMSE:',rmse)
    print('MAE:',mae)
    print('MAE:',mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)

    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 1198.8293111469354
# MAE: 726.0528982162507
# MAE: 726.0528982162507
# R2 score 91.17706806392405
# ===================================
#
#
# Lasso
# Model Training Performance
# RMSE: 1198.713796345963
# MAE: 727.5667075725913
# MAE: 727.5667075725913
# R2 score 91.17876827281106
# ===================================
#
#
# Ridge
# Model Training Performance
# RMSE: 1198.8305077010386
# MAE: 726.081959079119
# MAE: 726.081959079119
# R2 score 91.17705045154075
# ===================================
#
#
# Elasticnet
# Model Training Performance
# RMSE: 1629.5349717231074
# MAE: 1133.4879105147706
# MAE: 1133.4879105147706
# R2 score 83.69857410695968
# ===================================
#
#
# SVR
# Model Training Performance
# RMSE: 2005.529649441653
# MAE: 985.1820321551087
# MAE: 985.1820321551087
# R2 score 75.30799267793998
# ===================================
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[71], line 17
#      15 for i in range(len(list(models))):
#      16     model = list(models.values())[i]
# ---> 17     model.fit(x_train,y_train)
#      19     # make predictions
#      20     y_pred=model.predict(x_test)
#
# File c:\Users\santo\OneDrive\Desktop\ml_project\.venv\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\santo\OneDrive\Desktop\ml_project\.venv\Lib\site-packages\sklearn\tree\_classes.py:1019, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     988 @_fit_context(prefer_skip_nested_validation=True)
#     989 def fit(self, X, y, sample_weight=None, check_input=True):
#     990     """Build a decision tree classifier from the training set (X, y).
#     991
#     992     Parameters
#    (...)
#    1016         Fitted estimator.
#    1017     """
# -> 1019     super()._fit(
#    1020         X,
#    1021         y,
#    1022         sample_weight=sample_weight,
#    1023         check_input=check_input,
#    1024     )
#    1025     return self
#
# File c:\Users\santo\OneDrive\Desktop\ml_project\.venv\Lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# File _tree.pyx:153, in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# File _tree.pyx:268, in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# File _tree.pyx:923, in sklearn.tree._tree.Tree._add_node()
#
# File _tree.pyx:892, in sklearn.tree._tree.Tree._resize_c()
#
# File _utils.pyx:29, in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 9143582720 bytes
